# %%
from astropy import units as u
from synphot import units, SourceSpectrum
from synphot.models import BlackBodyNorm1D, GaussianFlux1D

# %%
g_abs = SourceSpectrum(GaussianFlux1D, amplitude=1*u.mJy,
                       mean=4000, stddev=20)
g_em = SourceSpectrum(GaussianFlux1D,
                      total_flux=3.5e-13*u.erg/(u.cm**2 * u.s),
                      mean=3000, fwhm=100)
bb = SourceSpectrum(BlackBodyNorm1D, temperature=6000)

# %%
sp = 2 * bb + g_em - g_abs
sp.plot(left=1, right=7000)

# %%
g_abs.plot(left=3000,right=8000)

# %%
sp(0.3 * u.micron)
# Out:
# <Quantity 0.00129536 PHOTLAM>

# %%
sp(0.3 * u.micron, flux_unit=units.FLAM)
# Out:
# <Quantity 8.57718043e-15 FLAM>

# %%
sp(sp.waveset)
# Out:
# <Quantity [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#            4.47483872e-05, 4.34265235e-05, 4.21423946e-05] PHOTLAM>

# %%
print(sp)
# Out:
# SourceSpectrum at z=0.0
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: ([0] | [1]) + [2] - [3]
# Components:
#     [0]: <BlackBodyNorm1D(temperature=6000.)>
#
#     [1]: <Scale(factor=2.)>
#
#     [2]: <GaussianFlux1D(amplitude=0.00049657, mean=3000., stddev=42.46609001)>
#
#     [3]: <GaussianFlux1D(amplitude=0.0003773, mean=4000., stddev=20.)>
# Parameters:
#     temperature_0 factor_1      amplitude_2      ... mean_3 stddev_3
#     ------------- -------- --------------------- ... ------ --------
#            6000.0      2.0 0.0004965698607312611 ... 4000.0     20.0

# %%
sp.z = 0.2
print(sp)
# Out:
# SourceSpectrum at z=0.2
# Model: CompoundModel
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Expression: [0] | ([1] | [2]) + [3] - [4]
# Components:
#     [0]: <RedshiftScaleFactor(z=-0.16666667)>
#
#     [1]: <BlackBodyNorm1D(temperature=6000.)>
#
#     [2]: <Scale(factor=2.)>
#
#     [3]: <GaussianFlux1D(amplitude=0.00049657, mean=3000., stddev=42.46609001)>
#
#     [4]: <GaussianFlux1D(amplitude=0.0003773, mean=4000., stddev=20.)>
# Parameters:
#             z_0          temperature_1 factor_2 ... mean_4 stddev_4
#     -------------------- ------------- -------- ... ------ --------
#     -0.16666666666666663        6000.0      2.0 ... 4000.0     20.0

# %%
from synphot import SpectralElement
from synphot.models import Box1D
bp = SpectralElement(Box1D, amplitude=1, x_0=4000, width=2000)

# %%
sp_rn = sp.normalize(1 * u.Jy, band=bp)
sp_rn.integrate()
# Out:
# <Quantity 12540.4613615 ph / (s cm2)>

# %%
from synphot import Observation
obs = Observation(sp_rn, bp)

# %%
import numpy as np
area = np.pi* (1 * u.m) ** 2
area
obs.countrate(area=area)
# Out:
# <Quantity 24219649.46880912 ct / s>
